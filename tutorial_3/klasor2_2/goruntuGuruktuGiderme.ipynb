# %% [markdown]
# ## GÖRÜNTÜ GÜRÜLTÜ GİDERME

# %%
import numpy as np
import cv2
import matplotlib.pyplot  as plt

# %%
img = cv2.imread(r"materyal\bear.png")
dst = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,15)

# %%
plt.subplot(121)
plt.imshow(img)

plt.subplot(122)
plt.imshow(dst)

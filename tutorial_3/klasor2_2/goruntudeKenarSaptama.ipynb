# %% [markdown]
# ## GÖRÜNTÜDE KENAR SAPTAMA

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"materyal\elephant.png")
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

edges = cv2.Canny(imgRGB, 100, 700)

fig, axs =plt.subplots(1,2, figsize=(15,15))
axs[0].imshow(imgRGB)
axs[0].set_title("Original Image")

axs[1].imshow(edges, cmap='gray')
axs[1].set_title("Edge Image")

for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

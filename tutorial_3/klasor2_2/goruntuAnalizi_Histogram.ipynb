# %% [markdown]
# ### HİSTOGRAM İLE GÖRÜNTÜ ANALİZİ

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread(r"materyal\flowers.png")
cv2.imshow("Flowers",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
histr = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(histr)
plt.show()

# %%
plt.hist(img.ravel(),256,[0,256])
plt.show()
# Out:
# C:\Users\polat\AppData\Local\Temp\ipykernel_15392\3269869568.py:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(),256,[0,256])
